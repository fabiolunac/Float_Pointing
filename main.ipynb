# %%
from funcoes import read_file
import matplotlib.pyplot as plt
import numpy as np
import scipy.signal as signal
import pandas as pd

nb_mantissa = 23
nb_expo = 8

# %% [markdown]
# Coeficientes

# %%
Zn1 = [-0.0030]
Zd1 = [1.0000, -0.9978]

Zn2 = [0.7264,    0.4282]
Zd2 = [1.0000,    1.0489,    0.2886]

Zn3 = [-3.2489,   -0.3488]
Zd3 = [1.0000,   -0.0280,    0.1635]

Zn4 = [2.5889]
Zd4 = [1.0000,   -0.3644]

Zn5 = [-0.0635]
Zd5 = [1.0000,   -9.8459e-04]

Zn6 = [1.0494e-04]
Zd6 = [1.0000,   -3.3924e-13]

# Numerador
Znti = [4.294341492410895e-23,
            2.410259936829204e-09,
                1.361884841455440e-08,
                    -4.120546556616038e-09,
                        -9.988893287934183e-09,
                            -1.906299572480522e-09,
                                -1.381565400439083e-11,
                                    -2.560176577052387e-17,
                                                            0]

# Denominador
Zdti = [1.444400000000000e-08,
          -4.944897983017996e-09,
              -8.723804374709209e-09,
                  -5.868442605271617e-10,
                      -3.124085233920797e-10,
                          -6.992432687036571e-11,
                              2.478522822801157e-10,
                                    -2.439636477041001e-13,
                                        8.276140953857137e-26]

# %%
# -------------- Definição do Sinal -------------- #
N = 60
x = np.zeros(N)
x[0] = 1

# %% [markdown]
# ### Análise IIR 1

# %%
# -------------- Resposta ao Impulso Ideal -------------- #
y1_ideal = signal.lfilter(Zn1, Zd1, x)


# -------------- Leitura dos Sinais -------------- #
# IIR1
iir1_path = "iir1_out.txt"
iir1_out = read_file(iir1_path, nb_mantissa, nb_expo)
iir1_out = np.array(iir1_out)
iir1_out = iir1_out[:, 0]

erro1 = y1_ideal - iir1_out[0:N]

print(f'Erro máximo: {max(erro1)}')

plt.figure()
plt.subplot(311)
plt.stem(y1_ideal)
plt.title('Resposta ao Impulso Ideal')

plt.subplot(312)
plt.stem(iir1_out[0:N])
plt.title('Resposta ao Impulso Simulada')

plt.subplot(313)
plt.stem(erro1)
plt.title('Erro')

plt.tight_layout()
# Out:
# Erro máximo: -5.8232149762979e-06

# %% [markdown]
# ### Análise IIR2

# %%
# -------------- Resposta ao Impulso Ideal -------------- #
y2_ideal = signal.lfilter(Zn2, Zd2, x)


# -------------- Leitura dos Sinais -------------- #
# IIR1
iir2_path = "iir2_out.txt"
iir2_out = read_file(iir2_path, nb_mantissa, nb_expo)
iir2_out = np.array(iir2_out)
iir2_out = iir2_out[:, 0]

erro2 = y2_ideal - iir2_out[0:N]

print(f'Erro máximo: {max(erro2)}')

plt.figure()
plt.subplot(311)
plt.stem(y2_ideal)
plt.title('Resposta ao Impulso Ideal')

plt.subplot(312)
plt.stem(iir2_out[0:N])
plt.title('Resposta ao Impulso Simulada')

plt.subplot(313)
plt.stem(erro2)
plt.title('Erro')

plt.tight_layout()
# Out:
# Erro máximo: 1.2231442100829604e-07

# %% [markdown]
# ### Análise IIR3

# %%
# -------------- Resposta ao Impulso Ideal -------------- #
y3_ideal = signal.lfilter(Zn3, Zd3, x)


# -------------- Leitura dos Sinais -------------- #
# IIR1
iir3_path = "iir3_out.txt"
iir3_out = read_file(iir3_path, nb_mantissa, nb_expo)
iir3_out = np.array(iir3_out)
iir3_out = iir3_out[:, 0]

erro3 = y3_ideal - iir3_out[0:N]

print(f'Erro máximo: {max(erro3)}')

plt.figure()
plt.subplot(311)
plt.stem(y3_ideal)
plt.title('Resposta ao Impulso Ideal')

plt.subplot(312)
plt.stem(iir3_out[0:N])
plt.title('Resposta ao Impulso Simulada')

plt.subplot(313)
plt.stem(erro3)
plt.title('Erro')

plt.tight_layout()
# Out:
# Erro máximo: 5.3028051727466163e-08

# %% [markdown]
# ### Análise IIR4

# %%
# -------------- Resposta ao Impulso Ideal -------------- #
y4_ideal = signal.lfilter(Zn4, Zd4, x)


# -------------- Leitura dos Sinais -------------- #
# IIR1
iir4_path = "iir4_out.txt"
iir4_out = read_file(iir4_path, nb_mantissa, nb_expo)
iir4_out = np.array(iir4_out)
iir4_out = iir4_out[:, 0]

erro4 = y4_ideal - iir4_out[0:N]

print(f'Erro máximo: {max(erro4)}')

plt.figure()
plt.subplot(311)
plt.stem(y4_ideal)
plt.title('Resposta ao Impulso Ideal')

plt.subplot(312)
plt.stem(iir4_out[0:N])
plt.title('Resposta ao Impulso Simulada')

plt.subplot(313)
plt.stem(erro4)
plt.title('Erro')

plt.tight_layout()
# Out:
# Erro máximo: 3.875732423885836e-07

# %% [markdown]
# ### Análise IIR5

# %%
# -------------- Resposta ao Impulso Ideal -------------- #
y5_ideal = signal.lfilter(Zn5, Zd5, x)


# -------------- Leitura dos Sinais -------------- #
# IIR1
iir5_path = "iir5_out.txt"
iir5_out = read_file(iir5_path, nb_mantissa, nb_expo)
iir5_out = np.array(iir5_out)
iir5_out = iir5_out[:, 0]

erro5 = y5_ideal - iir5_out[0:N]

print(f'Erro máximo: {max(erro5)}')

plt.figure()
plt.subplot(311)
plt.stem(y5_ideal[0:N])
plt.title('Resposta ao Impulso Ideal')

plt.subplot(312)
plt.stem(iir5_out[0:N])
plt.title('Resposta ao Impulso Simulada')

plt.subplot(313)
plt.stem(erro5[0:N])
plt.title('Erro')

plt.tight_layout()
# Out:
# Erro máximo: -2.540057437400223e-179

# %% [markdown]
# ### Análise IIR6

# %%
# -------------- Resposta ao Impulso Ideal -------------- #
y6_ideal = signal.lfilter(Zn6, Zd6, x)


# -------------- Leitura dos Sinais -------------- #
# IIR1
iir6_path = "iir6_out.txt"
iir6_out = read_file(iir6_path, nb_mantissa, nb_expo)
iir6_out = np.array(iir6_out)
iir6_out = iir6_out[:, 0]

erro6 = y6_ideal - iir6_out[0:N]

print(f'Erro máximo: {max(erro6)}')


plt.figure()
plt.subplot(311)
plt.stem(y6_ideal[0:N])
plt.title('Resposta ao Impulso Ideal')

plt.subplot(312)
plt.stem(iir6_out[0:N])
plt.title('Resposta ao Impulso Simulada')

plt.subplot(313)
plt.stem(erro6[0:N])
plt.title('Erro')

plt.tight_layout()
# Out:
# Erro máximo: 3.738967415949756e-24

# %% [markdown]
# ### Análise IIR Final

# %%
y_ideal = y1_ideal + y2_ideal + y3_ideal + y4_ideal + y5_ideal + y6_ideal

# -------------- Leitura dos Sinais -------------- #
# IIR1
iir_path = "iir_out.txt"
iir_out = read_file(iir_path, nb_mantissa, nb_expo)
iir_out = np.array(iir_out)
iir_out = iir_out[:, 0]

erro = y_ideal - iir_out[0:N]

print(f'Erro máximo: {max(erro)}')


plt.figure()
plt.subplot(311)
plt.stem(y_ideal[0:N])
plt.title('Resposta ao Impulso Ideal')

plt.subplot(312)
plt.stem(iir_out[0:N])
plt.title('Resposta ao Impulso Simulada')

plt.subplot(313)
plt.stem(erro[0:N])
plt.title('Erro')

plt.tight_layout()

print(max(iir_out[0:N]))
# Out:
# Erro máximo: 1.4301920958637027e-07
# 1.0000686645507812

# %% [markdown]
# ### Filtragem Completa

# %%
# -------------- Resposta ao Impulso Ideal -------------- #
y_full_ideal = signal.lfilter(Znti, Zdti, x)


# -------------- Leitura dos Sinais -------------- #
# IIR1
iirfull_path = "iir_full.txt"
iirfull_out = read_file(iirfull_path, nb_mantissa, nb_expo)
iirfull_out = np.array(iirfull_out)
iirfull_out = iirfull_out[:, 0]

erro_full = y_full_ideal - iirfull_out[0:N]

print(f'Erro máximo: {max(erro_full)}')


plt.figure()
plt.subplot(311)
plt.stem(y_full_ideal[0:N])
plt.title('Resposta ao Impulso Ideal')

plt.subplot(312)
plt.stem(iirfull_out[0:N])
plt.title('Resposta ao Impulso Simulada')

plt.subplot(313)
plt.stem(erro_full[0:N])
plt.title('Erro')

plt.tight_layout()
# Out:
# Erro máximo: 3.838374966549929e-07

# %% [markdown]
# ### Comparação de Filtragens

# %%
erro_final = iir_out[0:N] - iirfull_out[0:N]

plt.figure()
plt.subplot(311)
plt.stem(iir_out[0:N])
plt.title('Resposta ao Impulso Ideal')

plt.subplot(312)
plt.stem(iirfull_out[0:N])
plt.title('Resposta ao Impulso Simulada')

plt.subplot(313)
plt.stem(erro_final[0:N])
plt.title('Erro')

plt.tight_layout()
